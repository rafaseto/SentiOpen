# %%
from dotenv import load_dotenv
from utils import fetch_issues_from_query, save_issues_to_postgres, fetch_comments_for_issues
import os
import psycopg

# %% [markdown]
# ### Getting the GitHub token from the .env variables

# %%
load_dotenv()
GITHUB_TOKEN = os.getenv('GITHUB_TOKEN')

# %% [markdown]
# ### Connecting to the local Postgres

# %%
repo_owner = "microsoft"
repo_name = "vscode"
dbname = "vscode_data_02"

DATABASE_CONFIG = {
    "dbname": dbname,
    "user": "postgres",
    "password": "postgres",
    "host": "localhost",
    "port": 5432,
}

conn = psycopg.connect(**DATABASE_CONFIG)
cursor = conn.cursor()

# %% [markdown]
# ### Getting the issues through a GitHub query

# %%
query = 'repo:microsoft/vscode is:issue is:closed milestone:"March 2025"'

issues = fetch_issues_from_query(query, GITHUB_TOKEN)
# Out:
# 2025-05-29 17:00:49,019 - INFO - Number of collected issues: 330

# %% [markdown]
# ### Saving the issues in the Postgres

# %%
# save_issues_to_postgres(conn, issues, '1.99', 'microsoft', 'vscode')

# %% [markdown]
# ### Getting the comments of all issues

# %%
comments = fetch_comments_for_issues(
    issues=issues,
    repo_owner='microsoft',
    repo_name='vscode',
    token=GITHUB_TOKEN
)
# Out:
# 2025-05-29 17:02:01,006 - INFO - Fetching comments for issue #245232 --- 1/330
# 2025-05-29 17:02:16,500 - INFO - Fetching comments for issue #245202 --- 2/330
# 2025-05-29 17:02:24,978 - INFO - Fetching comments for issue #245066 --- 3/330
# 2025-05-29 17:02:35,916 - INFO - Fetching comments for issue #245040 --- 4/330
# 2025-05-29 17:02:57,417 - INFO - Fetching comments for issue #244995 --- 5/330
# 2025-05-29 17:02:58,175 - INFO - Fetching comments for issue #244982 --- 6/330
# 2025-05-29 17:02:59,587 - INFO - Fetching comments for issue #244946 --- 7/330
# 2025-05-29 17:03:00,820 - INFO - Fetching comments for issue #244936 --- 8/330
# 2025-05-29 17:03:02,207 - INFO - Fetching comments for issue #244928 --- 9/330
# 2025-05-29 17:03:02,876 - INFO - Fetching comments for issue #244915 --- 10/330
# 2025-05-29 17:03:03,514 - INFO - Fetching comments for issue #244894 --- 11/330
# 2025-05-29 17:03:04,847 - INFO - Fetching comments for issue #244889 --- 12/330
# 2025-05-29 17:03:05,539 - INFO - Fetching comments for issue #244802 --- 13/330
# 2025-05-29 17:03:06,171 - INFO - Fetching comments for issue #244781 --- 14/330
# 2025-05-29 17:03:06,760 - INFO - Fetching comments for issue #244752 --- 15/330
# 2025-05-29 17:03:07,430 - INFO - Fetching comments for issue #244748 --- 16/330
# 2025-05-29 17:03:08,737 - INFO - Fetching comments for issue #244730 --- 17/330
# 2025-05-29 17:03:09,989 - INFO - Fetching comments for issue #244714 --- 18/330
# 2025-05-29 17:03:10,627 - INFO - Fetching comments for issue #244686 --- 19/330
# 2025-05-29 17:03:12,156 - INFO - Fetching comments for issue #244666 --- 20/330
# 2025-05-29 17:03:12,856 - INFO - Fetching comments for issue #244663 --- 21/330
# 2025-05-29 17:03:13,502 - INFO - Fetching comments for issue #244656 --- 22/330
# 2025-05-29 17:03:14,786 - INFO - Fetching comments for issue #244651 --- 23/330
# 2025-05-29 17:09:04,024 - INFO - Fetching comments for issue #214220 --- 321/330
# 2025-05-29 17:09:05,363 - INFO - Fetching comments for issue #207409 --- 322/330
# 2025-05-29 17:09:06,818 - INFO - Fetching comments for issue #198766 --- 323/330
# 2025-05-29 17:09:08,192 - INFO - Fetching comments for issue #187709 --- 324/330
# 2025-05-29 17:09:09,507 - INFO - Fetching comments for issue #187407 --- 325/330
# 2025-05-29 17:09:10,749 - INFO - Fetching comments for issue #174021 --- 326/330
# 2025-05-29 17:09:12,331 - INFO - Fetching comments for issue #164153 --- 327/330
# 2025-05-29 17:09:13,579 - INFO - Fetching comments for issue #153712 --- 328/330
# 2025-05-29 17:09:14,945 - INFO - Fetching comments for issue #150354 --- 329/330
# 2025-05-29 17:09:16,225 - INFO - Fetching comments for issue #148942 --- 330/330
# 2025-05-29 17:09:17,556 - INFO - Finished fetching all of the comments.

# %%
len(comments)
# Out:
# 1195

# %%
comments
# Out:
# [{'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2769336437',
#   'html_url': 'https://github.com/microsoft/vscode/issues/245232#issuecomment-2769336437',
#   'issue_url': 'https://api.github.com/repos/microsoft/vscode/issues/245232',
#   'id': 2769336437,
#   'node_id': 'IC_kwDOAn8RLM6lELh1',
#   'user': {'login': 'deepak1556',
#    'id': 964386,
#    'node_id': 'MDQ6VXNlcjk2NDM4Ng==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/964386?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/deepak1556',
#    'html_url': 'https://github.com/deepak1556',
#    'followers_url': 'https://api.github.com/users/deepak1556/followers',
#    'following_url': 'https://api.github.com/users/deepak1556/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/deepak1556/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/deepak1556/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/deepak1556/subscriptions',
#    'organizations_url': 'https://api.github.com/users/deepak1556/orgs',
#    'repos_url': 'https://api.github.com/users/deepak1556/repos',
#    'events_url': 'https://api.github.com/users/deepak1556/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/deepak1556/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'created_at': '2025-04-01T13:18:45Z',
#   'updated_at': '2025-04-01T13:18:45Z',
#   'author_association': 'COLLABORATOR',
#   'body': '*Steps for verification:*\n\n* Install Postman VS Code extension and log in\n* Send a request to www.google.com\n* Verify the html response is formatted',
#   'reactions': {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2769336437/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2771501246',
#   'html_url': 'https://github.com/microsoft/vscode/issues/245040#issuecomment-2771501246',
#   'issue_url': 'https://api.github.com/repos/microsoft/vscode/issues/245040',
#   'id': 2771501246,
#   'node_id': 'IC_kwDOAn8RLM6lMcC-',
#   'user': {'login': 'dbaeumer',
#    'id': 1931590,
#    'node_id': 'MDQ6VXNlcjE5MzE1OTA=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1931590?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dbaeumer',
#    'html_url': 'https://github.com/dbaeumer',
#    'followers_url': 'https://api.github.com/users/dbaeumer/followers',
#    'following_url': 'https://api.github.com/users/dbaeumer/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/dbaeumer/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/dbaeumer/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/dbaeumer/subscriptions',
#    'organizations_url': 'https://api.github.com/users/dbaeumer/orgs',
#    'repos_url': 'https://api.github.com/users/dbaeumer/repos',
#    'events_url': 'https://api.github.com/users/dbaeumer/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/dbaeumer/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': True},
#   'created_at': '2025-04-02T06:51:19Z',
#   'updated_at': '2025-04-02T06:51:19Z',
#   'author_association': 'MEMBER',
#   'body': 'Verified using the steps from above and not seeing the dialog anymore',
#   'reactions': {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2771501246/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2761723131',
#   'html_url': 'https://github.com/microsoft/vscode/issues/244982#issuecomment-2761723131',
#   'issue_url': 'https://api.github.com/repos/microsoft/vscode/issues/244982',
#   'id': 2761723131,
#   'node_id': 'IC_kwDOAn8RLM6knIz7',
#   'user': {'login': 'benibenj',
#    'id': 44439583,
#    'node_id': 'MDQ6VXNlcjQ0NDM5NTgz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44439583?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/benibenj',
#    'html_url': 'https://github.com/benibenj',
#    'followers_url': 'https://api.github.com/users/benibenj/followers',
#    'following_url': 'https://api.github.com/users/benibenj/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/benibenj/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/benibenj/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/benibenj/subscriptions',
#    'organizations_url': 'https://api.github.com/users/benibenj/orgs',
#    'repos_url': 'https://api.github.com/users/benibenj/repos',
#    'events_url': 'https://api.github.com/users/benibenj/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/benibenj/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': True},
#   'created_at': '2025-03-28T15:40:11Z',
#   'updated_at': '2025-03-28T15:41:08Z',
#   'author_association': 'CONTRIBUTOR',
#   'body': 'A possible **candidate fix** could be to first check if the dragged data is "editor data" and if that is not the case, then check if it is image data. Maybe something like this:\n\n```typescript\nconst editorDragData = extractEditorsDropData(e);\nif (editorDragData.length === 0 && !containsDragType(e, DataTransfers.INTERNAL_URI_LIST) && containsDragType(e, Mimes.uriList) && ((containsDragType(e, Mimes.html) || containsDragType(e, Mimes.text)))) {\n\treturn this.resolveHTMLAttachContext(e);\n}\n\nreturn coalesce(await Promise.all(editorDragData.map(editorInput => {\n\treturn this.resolveAttachContext(editorInput);\n})));\n```\n\nI don\'t know if this might falsely classify some of your image drag data as "editor data" so please test it',
#   'reactions': {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2761723131/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2761950921',
#   'html_url': 'https://github.com/microsoft/vscode/issues/244982#issuecomment-2761950921',
#   'issue_url': 'https://api.github.com/repos/microsoft/vscode/issues/244982',
#   'id': 2761950921,
#   'node_id': 'IC_kwDOAn8RLM6koAbJ',
#   'user': {'login': 'justschen',
#    'id': 54879025,
#    'node_id': 'MDQ6VXNlcjU0ODc5MDI1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54879025?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/justschen',
#    'html_url': 'https://github.com/justschen',
#    'followers_url': 'https://api.github.com/users/justschen/followers',
#    'following_url': 'https://api.github.com/users/justschen/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/justschen/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/justschen/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/justschen/subscriptions',
#    'organizations_url': 'https://api.github.com/users/justschen/orgs',
#    'repos_url': 'https://api.github.com/users/justschen/repos',
#    'events_url': 'https://api.github.com/users/justschen/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/justschen/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': True},
#   'created_at': '2025-03-28T17:09:13Z',
#   'updated_at': '2025-03-28T17:29:09Z',
#   'author_association': 'COLLABORATOR',
#   'body': "note: this is only happening on windows, not on mac. will investigate further. safari is the main offender, since it doesn't provide `text/html` and only `text/plain` and `text/uri-list`. files from web do not work on mac.\n\ninterestingly on mac, for workspace/internal DND, we have the following:\n![Image](https://github.com/user-attachments/assets/b8de1f72-d992-4bd4-8685-f6eafe4f4300)\n\nbut on windows, folders have an additional `uri-list` data transfer type\n\nregardless, checking `const editorDragData = extractEditorsDropData(e);` is probably best, since all browsers on Windows have `text/html`",
#   'reactions': {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2761950921/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2762759775',
#   'html_url': 'https://github.com/microsoft/vscode/issues/244982#issuecomment-2762759775',
#   'issue_url': 'https://api.github.com/repos/microsoft/vscode/issues/244982',
#   'id': 2762759775,
#   'node_id': 'IC_kwDOAn8RLM6krF5f',
#   'user': {'login': 'vs-code-engineering[bot]',
#    'id': 122617954,
#    'node_id': 'BOT_kgDOB08AYg',
#    'avatar_url': 'https://avatars.githubusercontent.com/in/281319?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vs-code-engineering%5Bbot%5D',
#    'html_url': 'https://github.com/apps/vs-code-engineering',
#    'followers_url': 'https://api.github.com/users/vs-code-engineering%5Bbot%5D/followers',
#    'following_url': 'https://api.github.com/users/vs-code-engineering%5Bbot%5D/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/vs-code-engineering%5Bbot%5D/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/vs-code-engineering%5Bbot%5D/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/vs-code-engineering%5Bbot%5D/subscriptions',
#    'organizations_url': 'https://api.github.com/users/vs-code-engineering%5Bbot%5D/orgs',
#    'repos_url': 'https://api.github.com/users/vs-code-engineering%5Bbot%5D/repos',
#    'events_url': 'https://api.github.com/users/vs-code-engineering%5Bbot%5D/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/vs-code-engineering%5Bbot%5D/received_events',
#    'type': 'Bot',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'created_at': '2025-03-28T22:46:40Z',
#   'updated_at': '2025-03-28T22:46:40Z',
#   'author_association': 'NONE',
#   'body': '<!-- UNABLE_TO_LOCATE_COMMIT_MESSAGE -->\nIssue marked as unreleased but unable to locate closing commit in issue timeline. You can manually reference a commit by commenting `\\closedWith someCommitSha`, or directly add the `insiders-released` label if you know this has already been released',
#   'reactions': {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2762759775/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': {'id': 281319,
#    'client_id': 'Iv1.8a642b211332ec58',
#    'slug': 'vs-code-engineering',
#    'node_id': 'A_kwHOA6PZ4M4ABErn',
#    'owner': {'login': 'Visual-Studio-Code',
#     'id': 61069792,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjYxMDY5Nzky',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/61069792?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/Visual-Studio-Code',
#     'html_url': 'https://github.com/Visual-Studio-Code',
#     'followers_url': 'https://api.github.com/users/Visual-Studio-Code/followers',
#     'following_url': 'https://api.github.com/users/Visual-Studio-Code/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/Visual-Studio-Code/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/Visual-Studio-Code/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/Visual-Studio-Code/subscriptions',
#     'organizations_url': 'https://api.github.com/users/Visual-Studio-Code/orgs',
#     'repos_url': 'https://api.github.com/users/Visual-Studio-Code/repos',
#     'events_url': 'https://api.github.com/users/Visual-Studio-Code/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/Visual-Studio-Code/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'name': 'VS Code Engineering',
#    'description': 'This application is used for the following tasks:\r\n- [Community PR Checks](https://github.com/microsoft/vscode-engineering/blob/721d657e6d297ab472aef07b9a73d2836417bfeb/.github/actions/community-pr-check/src/main.ts#L19C9-L19C16)',
#    'external_url': 'https://code.visualstudio.com',
#    'html_url': 'https://github.com/apps/vs-code-engineering',
#    'created_at': '2023-01-13T13:34:40Z',
#    'updated_at': '2025-04-30T13:43:58Z',
#    'permissions': {'checks': 'write',
#     'contents': 'write',
#     'issues': 'write',
#     'metadata': 'read',
#     'pull_requests': 'write'},
#    'events': []}},
#  {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2762849264',
#   'html_url': 'https://github.com/microsoft/vscode/issues/244982#issuecomment-2762849264',
#   'issue_url': 'https://api.github.com/repos/microsoft/vscode/issues/244982',
#   'id': 2762849264,
#   'node_id': 'IC_kwDOAn8RLM6krbvw',
#   'user': {'login': 'rzhao271',
#    'id': 7199958,
#    'node_id': 'MDQ6VXNlcjcxOTk5NTg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7199958?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rzhao271',
#    'html_url': 'https://github.com/rzhao271',
#    'followers_url': 'https://api.github.com/users/rzhao271/followers',
#    'following_url': 'https://api.github.com/users/rzhao271/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rzhao271/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rzhao271/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rzhao271/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rzhao271/orgs',
#    'repos_url': 'https://api.github.com/users/rzhao271/repos',
#    'events_url': 'https://api.github.com/users/rzhao271/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rzhao271/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': True},
#   'created_at': '2025-03-28T23:31:51Z',
#   'updated_at': '2025-03-28T23:31:51Z',
#   'author_association': 'CONTRIBUTOR',
#   'body': '\\closedWith 87ce711',
#   'reactions': {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2762849264/reactions',
#    'total_count': 1,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 1,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2762527089',
#   'html_url': 'https://github.com/microsoft/vscode/issues/244946#issuecomment-2762527089',
#   'issue_url': 'https://api.github.com/repos/microsoft/vscode/issues/244946',
#   'id': 2762527089,
#   'node_id': 'IC_kwDOAn8RLM6kqNFx',
#   'user': {'login': 'TylerLeonhardt',
#    'id': 2644648,
#    'node_id': 'MDQ6VXNlcjI2NDQ2NDg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2644648?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/TylerLeonhardt',
#    'html_url': 'https://github.com/TylerLeonhardt',
#    'followers_url': 'https://api.github.com/users/TylerLeonhardt/followers',
#    'following_url': 'https://api.github.com/users/TylerLeonhardt/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/TylerLeonhardt/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/TylerLeonhardt/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/TylerLeonhardt/subscriptions',
#    'organizations_url': 'https://api.github.com/users/TylerLeonhardt/orgs',
#    'repos_url': 'https://api.github.com/users/TylerLeonhardt/repos',
#    'events_url': 'https://api.github.com/users/TylerLeonhardt/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/TylerLeonhardt/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': True},
#   'created_at': '2025-03-28T21:11:02Z',
#   'updated_at': '2025-03-28T21:11:02Z',
#   'author_association': 'MEMBER',
#   'body': '/closedWith https://github.com/microsoft/vscode/commit/2dea7feb8230ba026348e3c990fbca316630f75a',
#   'reactions': {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2762527089/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2760288982',
#   'html_url': 'https://github.com/microsoft/vscode/issues/244936#issuecomment-2760288982',
#   'issue_url': 'https://api.github.com/repos/microsoft/vscode/issues/244936',
#   'id': 2760288982,
#   'node_id': 'IC_kwDOAn8RLM6khqrW',
#   'user': {'login': 'bpasero',
#    'id': 900690,
#    'node_id': 'MDQ6VXNlcjkwMDY5MA==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/900690?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bpasero',
#    'html_url': 'https://github.com/bpasero',
#    'followers_url': 'https://api.github.com/users/bpasero/followers',
#    'following_url': 'https://api.github.com/users/bpasero/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/bpasero/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/bpasero/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/bpasero/subscriptions',
#    'organizations_url': 'https://api.github.com/users/bpasero/orgs',
#    'repos_url': 'https://api.github.com/users/bpasero/repos',
#    'events_url': 'https://api.github.com/users/bpasero/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/bpasero/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': True},
#   'created_at': '2025-03-28T05:58:49Z',
#   'updated_at': '2025-03-28T05:58:49Z',
#   'author_association': 'MEMBER',
#   'body': 'Thanks, yeah unfortunately we need to play catch up game here...',
#   'reactions': {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2760288982/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2762195277',
#   'html_url': 'https://github.com/microsoft/vscode/issues/244936#issuecomment-2762195277',
#   'issue_url': 'https://api.github.com/repos/microsoft/vscode/issues/244936',
#   'id': 2762195277,
#   'node_id': 'IC_kwDOAn8RLM6ko8FN',
#   'user': {'login': 'roblourens',
#    'id': 323878,
#    'node_id': 'MDQ6VXNlcjMyMzg3OA==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/323878?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/roblourens',
#    'html_url': 'https://github.com/roblourens',
#    'followers_url': 'https://api.github.com/users/roblourens/followers',
#    'following_url': 'https://api.github.com/users/roblourens/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/roblourens/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/roblourens/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/roblourens/subscriptions',
#    'organizations_url': 'https://api.github.com/users/roblourens/orgs',
#    'repos_url': 'https://api.github.com/users/roblourens/repos',
#    'events_url': 'https://api.github.com/users/roblourens/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/roblourens/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': True},
#   'created_at': '2025-03-28T19:00:16Z',
#   'updated_at': '2025-03-28T19:00:39Z',
#   'author_association': 'MEMBER',
#   'body': "I'd like to have one source of truth for this, however the extension has the extra quirk of introducing this dynamic message about telemetry for internal users, not sure if we have the info to apply that on the core side",
#   'reactions': {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2762195277/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2762219828',
#   'html_url': 'https://github.com/microsoft/vscode/issues/244936#issuecomment-2762219828',
#   'issue_url': 'https://api.github.com/repos/microsoft/vscode/issues/244936',
#   'id': 2762219828,
#   'node_id': 'IC_kwDOAn8RLM6kpCE0',
#   'user': {'login': 'bpasero',
#    'id': 900690,
#    'node_id': 'MDQ6VXNlcjkwMDY5MA==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/900690?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bpasero',
#    'html_url': 'https://github.com/bpasero',
#    'followers_url': 'https://api.github.com/users/bpasero/followers',
#    'following_url': 'https://api.github.com/users/bpasero/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/bpasero/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/bpasero/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/bpasero/subscriptions',
#    'organizations_url': 'https://api.github.com/users/bpasero/orgs',
#    'repos_url': 'https://api.github.com/users/bpasero/repos',
#    'events_url': 'https://api.github.com/users/bpasero/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/bpasero/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': True},
#   'created_at': '2025-03-28T19:12:52Z',
#   'updated_at': '2025-03-28T19:13:09Z',
#   'author_association': 'MEMBER',
#   'body': 'That is only for MSFT internal right? But I do agree that we should try to move this out entirely from the extension if possible.',
#   'reactions': {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2762219828/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2762544112',
#   'html_url': 'https://github.com/microsoft/vscode/issues/244936#issuecomment-2762544112',
#   'issue_url': 'https://api.github.com/repos/microsoft/vscode/issues/244936',
#   'id': 2762544112,
#   'node_id': 'IC_kwDOAn8RLM6kqRPw',
#   'user': {'login': 'TylerLeonhardt',
#    'id': 2644648,
#    'node_id': 'MDQ6VXNlcjI2NDQ2NDg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2644648?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/TylerLeonhardt',
#    'html_url': 'https://github.com/TylerLeonhardt',
#    'followers_url': 'https://api.github.com/users/TylerLeonhardt/followers',
#    'following_url': 'https://api.github.com/users/TylerLeonhardt/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/TylerLeonhardt/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/TylerLeonhardt/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/TylerLeonhardt/subscriptions',
#    'organizations_url': 'https://api.github.com/users/TylerLeonhardt/orgs',
#    'repos_url': 'https://api.github.com/users/TylerLeonhardt/repos',
#    'events_url': 'https://api.github.com/users/TylerLeonhardt/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/TylerLeonhardt/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': True},
#   'created_at': '2025-03-28T21:17:36Z',
#   'updated_at': '2025-03-28T21:17:36Z',
#   'author_association': 'MEMBER',
#   'body': '/closedWith https://github.com/microsoft/vscode/commit/23192aac955b0167f8ddf8059425e3d1bb5aa8f7',
#   'reactions': {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2762544112/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2760526310',
#   'html_url': 'https://github.com/microsoft/vscode/issues/244894#issuecomment-2760526310',
#   'issue_url': 'https://api.github.com/repos/microsoft/vscode/issues/244894',
#   'id': 2760526310,
#   'node_id': 'IC_kwDOAn8RLM6kiknm',
#   'user': {'login': 'benibenj',
#    'id': 44439583,
#    'node_id': 'MDQ6VXNlcjQ0NDM5NTgz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44439583?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/benibenj',
#    'html_url': 'https://github.com/benibenj',
#    'followers_url': 'https://api.github.com/users/benibenj/followers',
#    'following_url': 'https://api.github.com/users/benibenj/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/benibenj/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/benibenj/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/benibenj/subscriptions',
#    'organizations_url': 'https://api.github.com/users/benibenj/orgs',
#    'repos_url': 'https://api.github.com/users/benibenj/repos',
#    'events_url': 'https://api.github.com/users/benibenj/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/benibenj/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': True},
#   'created_at': '2025-03-28T08:21:33Z',
#   'updated_at': '2025-03-28T08:21:33Z',
#   'author_association': 'CONTRIBUTOR',
#   'body': 'Was fixed with yesterdays side by side computation fix',
#   'reactions': {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2760526310/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2762043988',
#   'html_url': 'https://github.com/microsoft/vscode/issues/244894#issuecomment-2762043988',
#   'issue_url': 'https://api.github.com/repos/microsoft/vscode/issues/244894',
#   'id': 2762043988,
#   'node_id': 'IC_kwDOAn8RLM6koXJU',
#   'user': {'login': 'osortega',
#    'id': 48293249,
#    'node_id': 'MDQ6VXNlcjQ4MjkzMjQ5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/48293249?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/osortega',
#    'html_url': 'https://github.com/osortega',
#    'followers_url': 'https://api.github.com/users/osortega/followers',
#    'following_url': 'https://api.github.com/users/osortega/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/osortega/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/osortega/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/osortega/subscriptions',
#    'organizations_url': 'https://api.github.com/users/osortega/orgs',
#    'repos_url': 'https://api.github.com/users/osortega/repos',
#    'events_url': 'https://api.github.com/users/osortega/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/osortega/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': True},
#   'created_at': '2025-03-28T17:49:03Z',
#   'updated_at': '2025-03-28T17:49:03Z',
#   'author_association': 'CONTRIBUTOR',
#   'body': 'LGTM\n<img width="468" alt="Image" src="https://github.com/user-attachments/assets/a331f3f2-f6ed-497b-b09b-412238b04b12" />',
#   'reactions': {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2762043988/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2759102162',
#   'html_url': 'https://github.com/microsoft/vscode/issues/244748#issuecomment-2759102162',
#   'issue_url': 'https://api.github.com/repos/microsoft/vscode/issues/244748',
#   'id': 2759102162,
#   'node_id': 'IC_kwDOAn8RLM6kdI7S',
#   'user': {'login': 'eleanorjboyd',
#    'id': 26030610,
#    'node_id': 'MDQ6VXNlcjI2MDMwNjEw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26030610?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/eleanorjboyd',
#    'html_url': 'https://github.com/eleanorjboyd',
#    'followers_url': 'https://api.github.com/users/eleanorjboyd/followers',
#    'following_url': 'https://api.github.com/users/eleanorjboyd/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/eleanorjboyd/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/eleanorjboyd/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/eleanorjboyd/subscriptions',
#    'organizations_url': 'https://api.github.com/users/eleanorjboyd/orgs',
#    'repos_url': 'https://api.github.com/users/eleanorjboyd/repos',
#    'events_url': 'https://api.github.com/users/eleanorjboyd/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/eleanorjboyd/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'created_at': '2025-03-27T18:49:50Z',
#   'updated_at': '2025-03-27T18:49:50Z',
#   'author_association': 'MEMBER',
#   'body': 'not seeing this UI? Is this sidebar, unified chat, with agent mode?',
#   'reactions': {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2759102162/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2759145561',
#   'html_url': 'https://github.com/microsoft/vscode/issues/244748#issuecomment-2759145561',
#   'issue_url': 'https://api.github.com/repos/microsoft/vscode/issues/244748',
#   'id': 2759145561,
#   'node_id': 'IC_kwDOAn8RLM6kdThZ',
#   'user': {'login': 'amunger',
#    'id': 2019016,
#    'node_id': 'MDQ6VXNlcjIwMTkwMTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2019016?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amunger',
#    'html_url': 'https://github.com/amunger',
#    'followers_url': 'https://api.github.com/users/amunger/followers',
#    'following_url': 'https://api.github.com/users/amunger/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amunger/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amunger/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amunger/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amunger/orgs',
#    'repos_url': 'https://api.github.com/users/amunger/repos',
#    'events_url': 'https://api.github.com/users/amunger/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amunger/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'created_at': '2025-03-27T19:10:46Z',
#   'updated_at': '2025-03-27T19:10:46Z',
#   'author_association': 'COLLABORATOR',
#   'body': "Still shows, but now there are actions to be taken, so that makes sense. Let me know if there's something else to verify.\n\n![Image](https://github.com/user-attachments/assets/7747d69d-3e44-4bfb-9d44-96f98fbde28d)",
#   'reactions': {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2759145561/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2760405249',
#   'html_url': 'https://github.com/microsoft/vscode/issues/244748#issuecomment-2760405249',
#   'issue_url': 'https://api.github.com/repos/microsoft/vscode/issues/244748',
#   'id': 2760405249,
#   'node_id': 'IC_kwDOAn8RLM6kiHEB',
#   'user': {'login': 'jrieken',
#    'id': 1794099,
#    'node_id': 'MDQ6VXNlcjE3OTQwOTk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1794099?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jrieken',
#    'html_url': 'https://github.com/jrieken',
#    'followers_url': 'https://api.github.com/users/jrieken/followers',
#    'following_url': 'https://api.github.com/users/jrieken/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jrieken/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jrieken/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jrieken/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jrieken/orgs',
#    'repos_url': 'https://api.github.com/users/jrieken/repos',
#    'events_url': 'https://api.github.com/users/jrieken/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jrieken/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': True},
#   'created_at': '2025-03-28T07:10:25Z',
#   'updated_at': '2025-03-28T07:10:33Z',
#   'author_association': 'MEMBER',
#   'body': 'we actually changed that it will now always show',
#   'reactions': {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2760405249/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2755767482',
#   'html_url': 'https://github.com/microsoft/vscode/issues/244730#issuecomment-2755767482',
#   'issue_url': 'https://api.github.com/repos/microsoft/vscode/issues/244730',
#   'id': 2755767482,
#   'node_id': 'IC_kwDOAn8RLM6kQay6',
#   'user': {'login': 'roblourens',
#    'id': 323878,
#    'node_id': 'MDQ6VXNlcjMyMzg3OA==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/323878?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/roblourens',
#    'html_url': 'https://github.com/roblourens',
#    'followers_url': 'https://api.github.com/users/roblourens/followers',
#    'following_url': 'https://api.github.com/users/roblourens/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/roblourens/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/roblourens/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/roblourens/subscriptions',
#    'organizations_url': 'https://api.github.com/users/roblourens/orgs',
#    'repos_url': 'https://api.github.com/users/roblourens/repos',
#    'events_url': 'https://api.github.com/users/roblourens/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/roblourens/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': True},
#   'created_at': '2025-03-26T21:17:19Z',
#   'updated_at': '2025-03-26T21:17:19Z',
#   'author_association': 'MEMBER',
#   'body': 'Ugh probably from https://github.com/microsoft/vscode/pull/244396/files',
#   'reactions': {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2755767482/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2832153529',
#   'html_url': 'https://github.com/microsoft/vscode/issues/244686#issuecomment-2832153529',
#   'issue_url': 'https://api.github.com/repos/microsoft/vscode/issues/244686',
#   'id': 2832153529,
#   'node_id': 'IC_kwDOAn8RLM6ozzu5',
#   'user': {'login': 'leonard520',
#    'id': 5118845,
#    'node_id': 'MDQ6VXNlcjUxMTg4NDU=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5118845?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/leonard520',
#    'html_url': 'https://github.com/leonard520',
#    'followers_url': 'https://api.github.com/users/leonard520/followers',
#    'following_url': 'https://api.github.com/users/leonard520/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/leonard520/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/leonard520/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/leonard520/subscriptions',
#    'organizations_url': 'https://api.github.com/users/leonard520/orgs',
#    'repos_url': 'https://api.github.com/users/leonard520/repos',
#    'events_url': 'https://api.github.com/users/leonard520/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/leonard520/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'created_at': '2025-04-26T13:17:02Z',
#   'updated_at': '2025-04-26T13:17:02Z',
#   'author_association': 'NONE',
#   'body': '@roblourens I meet a similar issue. In my vscode extension, I previously use the below command to execute prompt with agent mode.\n`await vscode.commands.executeCommand("workbench.action.chat.open", { query: prompt, mode: "agent", });`\n\nHowever, I notice that the session history may impact my prompt. So I change my code to\n```\nawait vscode.commands.executeCommand("workbench.action.chat.open"); // In case user doesn\'t have chat open.\nawait vscode.commands.executeCommand("workbench.action.chat.newEditSession", { agentMode: true, inputValue: prompt });\n        })\n```\nWith this code, I find that sometimes the operation will hang at the line of my core extension logic.\n```\nawait vscode.lm.invokeTool(toolName, options, token);\n```\n\nI check the tool invoke logic and find that it rely on session to find out `editSession`. I just suspect if my code trigger two sessions and mixed them up.\nhttps://github.com/microsoft/vscode/blob/2b7f830b37e0d103dfee3a561e4c8a1192587f54/src/vs/workbench/contrib/chat/common/tools/editFileTool.ts#L54\n\nI also wonder what\'s the correct way to open a new session to avoid the context being impact by history?',
#   'reactions': {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2832153529/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2832590506',
#   'html_url': 'https://github.com/microsoft/vscode/issues/244686#issuecomment-2832590506',
#   'issue_url': 'https://api.github.com/repos/microsoft/vscode/issues/244686',
#   'id': 2832590506,
#   'node_id': 'IC_kwDOAn8RLM6o1eaq',
#   'user': {'login': 'roblourens',
#    'id': 323878,
#    'node_id': 'MDQ6VXNlcjMyMzg3OA==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/323878?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/roblourens',
#    'html_url': 'https://github.com/roblourens',
#    'followers_url': 'https://api.github.com/users/roblourens/followers',
#    'following_url': 'https://api.github.com/users/roblourens/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/roblourens/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/roblourens/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/roblourens/subscriptions',
#    'organizations_url': 'https://api.github.com/users/roblourens/orgs',
#    'repos_url': 'https://api.github.com/users/roblourens/repos',
#    'events_url': 'https://api.github.com/users/roblourens/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/roblourens/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': True},
#   'created_at': '2025-04-26T20:18:48Z',
#   'updated_at': '2025-04-26T20:18:48Z',
#   'author_association': 'MEMBER',
#   'body': "@leonard520 I'm hoping this is fixed in https://github.com/microsoft/vscode/pull/247485/files, in the next Insiders. Lmk if not, thanks",
#   'reactions': {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2832590506/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2846134423',
#   'html_url': 'https://github.com/microsoft/vscode/issues/244686#issuecomment-2846134423',
#   'issue_url': 'https://api.github.com/repos/microsoft/vscode/issues/244686',
#   'id': 2846134423,
#   'node_id': 'IC_kwDOAn8RLM6ppJCX',
#   'user': {'login': 'leonard520',
#    'id': 5118845,
#    'node_id': 'MDQ6VXNlcjUxMTg4NDU=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5118845?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/leonard520',
#    'html_url': 'https://github.com/leonard520',
#    'followers_url': 'https://api.github.com/users/leonard520/followers',
#    'following_url': 'https://api.github.com/users/leonard520/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/leonard520/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/leonard520/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/leonard520/subscriptions',
#    'organizations_url': 'https://api.github.com/users/leonard520/orgs',
#    'repos_url': 'https://api.github.com/users/leonard520/repos',
#    'events_url': 'https://api.github.com/users/leonard520/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/leonard520/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'created_at': '2025-05-02T02:00:10Z',
#   'updated_at': '2025-05-02T02:00:10Z',
#   'author_association': 'NONE',
#   'body': '@roblourens I have verified that the issue has been fixed in insider perfectly. Thanks a lot for your quick support!',
#   'reactions': {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2846134423/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2752346461',
#   'html_url': 'https://github.com/microsoft/vscode/issues/244656#issuecomment-2752346461',
#   'issue_url': 'https://api.github.com/repos/microsoft/vscode/issues/244656',
#   'id': 2752346461,
#   'node_id': 'IC_kwDOAn8RLM6kDXld',
#   'user': {'login': 'meganrogge',
#    'id': 29464607,
#    'node_id': 'MDQ6VXNlcjI5NDY0NjA3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29464607?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/meganrogge',
#    'html_url': 'https://github.com/meganrogge',
#    'followers_url': 'https://api.github.com/users/meganrogge/followers',
#    'following_url': 'https://api.github.com/users/meganrogge/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/meganrogge/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/meganrogge/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/meganrogge/subscriptions',
#    'organizations_url': 'https://api.github.com/users/meganrogge/orgs',
#    'repos_url': 'https://api.github.com/users/meganrogge/repos',
#    'events_url': 'https://api.github.com/users/meganrogge/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/meganrogge/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': True},
#   'created_at': '2025-03-25T19:44:43Z',
#   'updated_at': '2025-03-25T19:44:43Z',
#   'author_association': 'CONTRIBUTOR',
#   'body': 'Also, there is no command registered as ` Merge Editor: Accept Merge ` and yet it exists in the dialog.',
#   'reactions': {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2752346461/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2752347523',
#   'html_url': 'https://github.com/microsoft/vscode/issues/244656#issuecomment-2752347523',
#   'issue_url': 'https://api.github.com/repos/microsoft/vscode/issues/244656',
#   'id': 2752347523,
#   'node_id': 'IC_kwDOAn8RLM6kDX2D',
#   'user': {'login': 'meganrogge',
#    'id': 29464607,
#    'node_id': 'MDQ6VXNlcjI5NDY0NjA3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29464607?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/meganrogge',
#    'html_url': 'https://github.com/meganrogge',
#    'followers_url': 'https://api.github.com/users/meganrogge/followers',
#    'following_url': 'https://api.github.com/users/meganrogge/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/meganrogge/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/meganrogge/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/meganrogge/subscriptions',
#    'organizations_url': 'https://api.github.com/users/meganrogge/orgs',
#    'repos_url': 'https://api.github.com/users/meganrogge/repos',
#    'events_url': 'https://api.github.com/users/meganrogge/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/meganrogge/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': True},
#   'created_at': '2025-03-25T19:45:18Z',
#   'updated_at': '2025-03-25T19:45:18Z',
#   'author_association': 'CONTRIBUTOR',
#   'body': 'I think we want `merge.acceptAllInput1` and `merge.acceptAllInput2` ',
#   'reactions': {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2752347523/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2762054851',
#   'html_url': 'https://github.com/microsoft/vscode/issues/244656#issuecomment-2762054851',
#   'issue_url': 'https://api.github.com/repos/microsoft/vscode/issues/244656',
#   'id': 2762054851,
#   'node_id': 'IC_kwDOAn8RLM6koZzD',
#   'user': {'login': 'rzhao271',
#    'id': 7199958,
#    'node_id': 'MDQ6VXNlcjcxOTk5NTg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7199958?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rzhao271',
#    'html_url': 'https://github.com/rzhao271',
#    'followers_url': 'https://api.github.com/users/rzhao271/followers',
#    'following_url': 'https://api.github.com/users/rzhao271/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rzhao271/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rzhao271/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rzhao271/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rzhao271/orgs',
#    'repos_url': 'https://api.github.com/users/rzhao271/repos',
#    'events_url': 'https://api.github.com/users/rzhao271/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rzhao271/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': True},
#   'created_at': '2025-03-28T17:54:03Z',
#   'updated_at': '2025-03-28T17:54:33Z',
#   'author_association': 'CONTRIBUTOR',
#   'body': '@meganrogge A Resolve in Merge Editor button shows up on Windows. Is that by design?\n\n![Resolve in Merge Editor button on top of merge editor accessibility help dialog](https://github.com/user-attachments/assets/65374837-982a-4292-aa02-1f0705e29fa9)',
#   'reactions': {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2762054851/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2762075765',
# ...
#    'eyes': 0},
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2545942747',
#   'html_url': 'https://github.com/microsoft/vscode/issues/236110#issuecomment-2545942747',
#   'issue_url': 'https://api.github.com/repos/microsoft/vscode/issues/236110',
#   'id': 2545942747,
#   'node_id': 'IC_kwDOAn8RLM6XwADb',
#   'user': {'login': 'jrieken',
#    'id': 1794099,
#    'node_id': 'MDQ6VXNlcjE3OTQwOTk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1794099?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jrieken',
#    'html_url': 'https://github.com/jrieken',
#    'followers_url': 'https://api.github.com/users/jrieken/followers',
#    'following_url': 'https://api.github.com/users/jrieken/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jrieken/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jrieken/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jrieken/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jrieken/orgs',
#    'repos_url': 'https://api.github.com/users/jrieken/repos',
#    'events_url': 'https://api.github.com/users/jrieken/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jrieken/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': True},
#   'created_at': '2024-12-16T15:32:03Z',
#   'updated_at': '2024-12-16T15:32:03Z',
#   'author_association': 'MEMBER',
#   'body': 'Looks like an issue with tabs, while generating code we do add decoration (for progress and then for having changes)',
#   'reactions': {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2545942747/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2422938297',
#   'html_url': 'https://github.com/microsoft/vscode/issues/231623#issuecomment-2422938297',
#   'issue_url': 'https://api.github.com/repos/microsoft/vscode/issues/231623',
#   'id': 2422938297,
#   'node_id': 'IC_kwDOAn8RLM6Qaxq5',
#   'user': {'login': 'isidorn',
#    'id': 1926584,
#    'node_id': 'MDQ6VXNlcjE5MjY1ODQ=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1926584?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/isidorn',
#    'html_url': 'https://github.com/isidorn',
#    'followers_url': 'https://api.github.com/users/isidorn/followers',
#    'following_url': 'https://api.github.com/users/isidorn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/isidorn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/isidorn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/isidorn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/isidorn/orgs',
#    'repos_url': 'https://api.github.com/users/isidorn/repos',
#    'events_url': 'https://api.github.com/users/isidorn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/isidorn/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': True},
#   'created_at': '2024-10-18T17:33:41Z',
#   'updated_at': '2024-10-18T17:33:41Z',
#   'author_association': 'CONTRIBUTOR',
#   'body': 'Thanks for reaching out. Let me try to answer your questions.\n \nThere are no plans to extend the February 2025 deadline. Compiler requirements for newer Node.js versions and the security push inside Microsoft will make it harder to support across all three architectures of the legacy server with the current sysroots.\n \n> Will support be going away at the *beginning* or the *end* of February?\n \nSupport will be removed in beginning of March 2025. February release of VS Code will be the last version to support legacy server\n \n> Will you be making an explicit change to disable legacy compatibility? Currently, there are a number of elements in play--the legacy server, a special `/tmp/vscode-skip-server-requirements-check` check, shell script checks, checks written in Rust, etc.\n \nYes, the following changes will be made:\na) Removal of the pipeline that builds the legacy server https://github.com/microsoft/vscode/blob/main/build/azure-pipelines/linux/product-build-linux-legacy-server.yml\nb) Update the checks in cli https://github.com/microsoft/vscode/blob/main/cli/src/util/prereqs.rs to exit with an error on platforms that used legacy server\nc) Drop the support for legacy server use in the version check script https://github.com/microsoft/vscode/blob/a77885d9e879023f87c852d5f089efb1399a3e75/resources/server/bin/helpers/check-requirements-linux.sh#L14\n \n> Would you be willing to provide a draft release with your planned changes so that we can be proactive in evaluating workarounds?\n \nYes, this is a reasonable ask, we can provide a custom insiders build to test by December.',
#   'reactions': {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2422938297/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2423051580',
#   'html_url': 'https://github.com/microsoft/vscode/issues/231623#issuecomment-2423051580',
#   'issue_url': 'https://api.github.com/repos/microsoft/vscode/issues/231623',
#   'id': 2423051580,
#   'node_id': 'IC_kwDOAn8RLM6QbNU8',
#   'user': {'login': 'reukiodo',
#    'id': 5169351,
#    'node_id': 'MDQ6VXNlcjUxNjkzNTE=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5169351?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/reukiodo',
#    'html_url': 'https://github.com/reukiodo',
#    'followers_url': 'https://api.github.com/users/reukiodo/followers',
#    'following_url': 'https://api.github.com/users/reukiodo/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/reukiodo/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/reukiodo/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/reukiodo/subscriptions',
#    'organizations_url': 'https://api.github.com/users/reukiodo/orgs',
#    'repos_url': 'https://api.github.com/users/reukiodo/repos',
#    'events_url': 'https://api.github.com/users/reukiodo/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/reukiodo/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'created_at': '2024-10-18T18:50:42Z',
#   'updated_at': '2024-10-18T18:50:42Z',
#   'author_association': 'NONE',
#   'body': 'Will there be an announcement prior to the release in order to disable automatic updates? Or even better some method to automatically STOP automatic updates prior to this breaking change?',
#   'reactions': {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2423051580/reactions',
#    'total_count': 5,
#    '+1': 4,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 1,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2423065945',
#   'html_url': 'https://github.com/microsoft/vscode/issues/231623#issuecomment-2423065945',
#   'issue_url': 'https://api.github.com/repos/microsoft/vscode/issues/231623',
#   'id': 2423065945,
#   'node_id': 'IC_kwDOAn8RLM6QbQ1Z',
#   'user': {'login': 'simozacca',
#    'id': 7095450,
#    'node_id': 'MDQ6VXNlcjcwOTU0NTA=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7095450?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/simozacca',
#    'html_url': 'https://github.com/simozacca',
#    'followers_url': 'https://api.github.com/users/simozacca/followers',
#    'following_url': 'https://api.github.com/users/simozacca/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/simozacca/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/simozacca/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/simozacca/subscriptions',
#    'organizations_url': 'https://api.github.com/users/simozacca/orgs',
#    'repos_url': 'https://api.github.com/users/simozacca/repos',
#    'events_url': 'https://api.github.com/users/simozacca/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/simozacca/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'created_at': '2024-10-18T18:59:44Z',
#   'updated_at': '2024-10-18T18:59:44Z',
#   'author_association': 'NONE',
#   'body': 'Our research groups at London universities, along with many hundreds of other colleagues in similar academic environments worldwide, have been unable to upgrade our servers due to factors beyond our control. We hope you understand that, in certain contexts, especially in academia, financial constraints and administrative processes make such changes less feasible and significantly slower.\n\nWe would greatly appreciate it if a solution could be provided that allows us to continue using VSCode remotely on our outdated servers. A possible approach could be pinning a stable reference version that, while no longer maintained, could still be used by those in similar circumstances (which we believe is a considerable number of users).\n\nWe appreciate your understanding, as VSCode remains an essential resource for our publicly funded research.',
#   'reactions': {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2423065945/reactions',
#    'total_count': 9,
#    '+1': 8,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 1,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2423104964',
#   'html_url': 'https://github.com/microsoft/vscode/issues/231623#issuecomment-2423104964',
#   'issue_url': 'https://api.github.com/repos/microsoft/vscode/issues/231623',
#   'id': 2423104964,
#   'node_id': 'IC_kwDOAn8RLM6QbaXE',
#   'user': {'login': 'reukiodo',
#    'id': 5169351,
#    'node_id': 'MDQ6VXNlcjUxNjkzNTE=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5169351?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/reukiodo',
#    'html_url': 'https://github.com/reukiodo',
#    'followers_url': 'https://api.github.com/users/reukiodo/followers',
#    'following_url': 'https://api.github.com/users/reukiodo/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/reukiodo/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/reukiodo/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/reukiodo/subscriptions',
#    'organizations_url': 'https://api.github.com/users/reukiodo/orgs',
#    'repos_url': 'https://api.github.com/users/reukiodo/repos',
#    'events_url': 'https://api.github.com/users/reukiodo/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/reukiodo/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'created_at': '2024-10-18T19:28:03Z',
#   'updated_at': '2024-10-18T19:28:03Z',
#   'author_association': 'NONE',
#   'body': 'Also, users of VSCode are not necessarily admins of the systems they utilize. Breaking VSCode users is just penalizing your users, especially when they are not in the ability to upgrade equipment they are required to use.',
#   'reactions': {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2423104964/reactions',
#    'total_count': 3,
#    '+1': 3,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2426234325',
#   'html_url': 'https://github.com/microsoft/vscode/issues/231623#issuecomment-2426234325',
#   'issue_url': 'https://api.github.com/repos/microsoft/vscode/issues/231623',
#   'id': 2426234325,
#   'node_id': 'IC_kwDOAn8RLM6QnWXV',
#   'user': {'login': 'isidorn',
#    'id': 1926584,
#    'node_id': 'MDQ6VXNlcjE5MjY1ODQ=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1926584?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/isidorn',
#    'html_url': 'https://github.com/isidorn',
#    'followers_url': 'https://api.github.com/users/isidorn/followers',
#    'following_url': 'https://api.github.com/users/isidorn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/isidorn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/isidorn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/isidorn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/isidorn/orgs',
#    'repos_url': 'https://api.github.com/users/isidorn/repos',
#    'events_url': 'https://api.github.com/users/isidorn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/isidorn/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': True},
#   'created_at': '2024-10-21T10:12:12Z',
#   'updated_at': '2024-10-21T10:13:34Z',
#   'author_association': 'CONTRIBUTOR',
#   'body': 'Thanks for your feedback.\n\nYes there will be announcement.\nYou may disable automatic updates of VS Code via the setting `"update.mode": "none"`.\n\nWe will consider making the last version of VS Code that connect to an unsupported OS accessible from our docs.',
#   'reactions': {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2426234325/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2429797386',
#   'html_url': 'https://github.com/microsoft/vscode/issues/231623#issuecomment-2429797386',
#   'issue_url': 'https://api.github.com/repos/microsoft/vscode/issues/231623',
#   'id': 2429797386,
#   'node_id': 'IC_kwDOAn8RLM6Q08QK',
#   'user': {'login': 'adamcolon',
#    'id': 1127969,
#    'node_id': 'MDQ6VXNlcjExMjc5Njk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1127969?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/adamcolon',
#    'html_url': 'https://github.com/adamcolon',
#    'followers_url': 'https://api.github.com/users/adamcolon/followers',
#    'following_url': 'https://api.github.com/users/adamcolon/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/adamcolon/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/adamcolon/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/adamcolon/subscriptions',
#    'organizations_url': 'https://api.github.com/users/adamcolon/orgs',
#    'repos_url': 'https://api.github.com/users/adamcolon/repos',
#    'events_url': 'https://api.github.com/users/adamcolon/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/adamcolon/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'created_at': '2024-10-22T16:57:30Z',
#   'updated_at': '2024-10-22T16:57:30Z',
#   'author_association': 'NONE',
#   'body': "I can assure you, many of us cannot have legacy systems upgraded.  Many of us are clients and we have no control over the hardware, but we must manage and update code on them.\n\nAs long as you provide a path to ignore the check and keep using the software bypassing the lockout, we're fine.\n\ntldr; there's no way for some of us to upgrade legacy hardware but we still need to do work on them",
#   'reactions': {'url': 'https://api.github.com/repos/microsoft/vscode/issues/comments/2429797386/reactions',
#    'total_count': 5,
#    '+1': 5,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None},
#  ...]
